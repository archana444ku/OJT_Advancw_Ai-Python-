# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve
from sklearn.model_selection import train_test_split, cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Load the dataset

df = pd.read_csv('heart_disease.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# ## 3. Encode Categorical Variables

# %%
# One-hot encode categorical variables
df = pd.get_dummies(df, columns=['cp', 'thal', 'slope'], drop_first=True)
df.head()
# Out:
#    age  sex  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  ca  \
# 0   63    1       145   233    1        0      150      0      2.3   0
# 1   37    1       130   250    0        1      187      0      3.5   0
# 2   41    0       130   204    0        0      172      0      1.4   0
# 3   56    1       120   236    0        1      178      0      0.8   0
# 4   57    0       120   354    0        1      163      1      0.6   0
#
#    target   cp_1   cp_2   cp_3  thal_2  thal_3  slope_1  slope_2
# 0       1  False  False   True   False   False    False    False
# 1       1  False   True  False    True   False    False    False
# 2       1   True  False  False    True   False    False     True
# 3       1   True  False  False    True   False    False     True
# 4       1  False  False  False    True   False    False     True

# %% [markdown]
# ## 4. Scale Numerical Features

# %%
from sklearn.preprocessing import StandardScaler

# Select numerical features
numerical_features = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# Scale numerical features
scaler = StandardScaler()
df[numerical_features] = scaler.fit_transform(df[numerical_features])
df.head()
# Out:
#         age  sex  trestbps      chol  fbs  restecg   thalach  exang   oldpeak  \
# 0  1.203130    1  0.621450  0.022783    1        0 -0.606284      0  0.834157
# 1 -1.873727    1 -0.462475  0.469680    0        1  1.557623      0  1.730565
# 2 -1.400365    0 -0.462475 -0.739571    0        0  0.680364      0  0.161851
# 3  0.374745    1 -1.185092  0.101647    0        1  1.031267      0 -0.286352
# 4  0.493086    0 -1.185092  3.203637    0        1  0.154008      1 -0.435754
#
#    ca  target   cp_1   cp_2   cp_3  thal_2  thal_3  slope_1  slope_2
# 0   0       1  False  False   True   False   False    False    False
# 1   0       1  False   True  False    True   False    False    False
# 2   0       1   True  False  False    True   False    False     True
# 3   0       1   True  False  False    True   False    False     True
# 4   0       1  False  False  False    True   False    False     True

# %% [markdown]
# ##  5. Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Pairplot to see the distribution and relationships
sns.pairplot(df)
plt.show()

# Distribution of the target variable
sns.countplot(x='target', data=df)
plt.show()

# %% [markdown]
# ## 6. Visualize Correlations

# %% [markdown]
# ## Split the Data

# %%
# Correlation matrix
corr_matrix = df.corr()

# Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
# Correlation matrix
corr_matrix = df.corr()

# Heatmap
plt.figure(figsize=(8, 12))
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
plt.show()

# %%
# Step 6: Visualize correlations between features and the target variable
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Distribution of the Target Variable

# %%
# Distribution of target variable
sns.countplot(x='target', data=df)
plt.title('Distribution of Target Variable')
plt.show()

# %% [markdown]
# ## Visualize correlations between features and the target variable

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## 8.  Split the data into training and testing sets

# %%
# split data into train and test sets
from sklearn.model_selection import train_test_split, cross_val_score
np.random.seed(42)

X_train, X_test, Y_train, Y_test =train_test_split(X,Y,test_size=0.2)
X_train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       2 from sklearn.model_selection import train_test_split, cross_val_score
#       3 np.random.seed(42)
# ----> 5 X_train, X_test, Y_train, Y_test =train_test_split(X,Y,test_size=0.2)
#       6 X_train.head()
#
# NameError: name 'X' is not defined
